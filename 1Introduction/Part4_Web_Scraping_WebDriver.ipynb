# %% [markdown]
# # Introduction

# %% [markdown]
# Aujourd'hui la plupart des sites web utilisent du JavaScript pour rendre le site plus dynamique et agréable mais aussi pour afficher la données.
#
# Pour ces sites, la première méthode abordée n'est pas efficace, car de nombreuses requêtes sont utilisées pour se connecter, afficher la donnée, naviguer, il faudrait prendre en compte toutes ces requêtes et les assembler pour simuler le comportement du site.
#
# **C'est le comportement de votre navigateur**, il compile toutes les interactions, les requêtes et génère du HTML permettant d'afficher l'interface graphique d'un site web.
#
# Pour palier ce problème on peut laisser le navigateur faire son travail et contrôler sa surcouche logiciel. Pour cela on peut prendre le contrôle d'un navigateur comme Chrome, Edge, Firefox ou Safari depuis un script Python.
#
# Pour cela, nous allons utiliser un package Python `Selenium` https://selenium-python.readthedocs.io/ qui permet d'instancier un navigateur et de le contrôler. Sélénium est beaucoup utilisé pour générer des tests automatiques de sites web.
#
# On peut trouver les drivers des différents browser :
# - Chrome:	https://sites.google.com/a/chromium.org/chromedriver/downloads
# - Edge:	https://developer.microsoft.com/en-us/microsoft-edge/tools/webdriver/
# - Firefox:	https://github.com/mozilla/geckodriver/releases
# - Safari:	https://webkit.org/blog/6900/webdriver-support-in-safari-10/

# %%
# !pip install selenium==4.0.0
# Out:
# Requirement already satisfied: selenium==4.0.0 in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (4.0.0)
# Requirement already satisfied: urllib3~=1.26 in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from urllib3[secure]~=1.26->selenium==4.0.0) (1.26.18)
# Requirement already satisfied: trio~=0.17 in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from selenium==4.0.0) (0.23.1)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from selenium==4.0.0) (0.11.1)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium==4.0.0) (23.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium==4.0.0) (2.4.0)
# Requirement already satisfied: idna in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium==4.0.0) (2.8)
# Requirement already satisfied: outcome in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium==4.0.0) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium==4.0.0) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium==4.0.0) (1.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium==4.0.0) (1.1.3)
# Requirement already satisfied: wsproto>=0.14 in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from trio-websocket~=0.9->selenium==4.0.0) (1.2.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from urllib3[secure]~=1.26->selenium==4.0.0) (23.3.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from urllib3[secure]~=1.26->selenium==4.0.0) (41.0.5)
# Requirement already satisfied: certifi in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from urllib3[secure]~=1.26->selenium==4.0.0) (2019.11.28)
# Requirement already satisfied: urllib3-secure-extra in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from urllib3[secure]~=1.26->selenium==4.0.0) (0.1.0)
# Requirement already satisfied: pycparser in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium==4.0.0) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\basti\appdata\local\programs\python\python310\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium==4.0.0) (0.14.0)

# %%
from selenium import webdriver

# %%
IS_LINUX = False

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# absl-py                      1.4.0
# ansi2html                    1.8.0
# anyio                        4.0.0
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# ast-scope                    0.3.1
# asttokens                    2.2.1
# astunparse                   1.6.3
# async-lru                    2.0.4
# attrs                        23.1.0
# autograd                     1.5
# Automat                      22.10.0
# Babel                        2.13.1
# backcall                     0.2.0
# beautifulsoup4               4.12.2
# bleach                       6.1.0
# branca                       0.6.0
# cachetools                   5.3.0
# certifi                      2019.11.28
# cffi                         1.16.0
# chardet                      3.0.4
# charset-normalizer           3.3.2
# click                        8.1.7
# click-plugins                1.1.1
# cligj                        0.7.2
# colorama                     0.4.3
# comm                         0.2.0
# constantly                   23.10.4
# coverage                     4.4
# cryptography                 41.0.5
# cssselect                    1.2.0
# cycler                       0.11.0
# dash                         2.13.0
# dash-bootstrap-components    1.5.0
# dash-core-components         2.0.0
# dash-html-components         2.0.0
# dash-table                   5.0.0
# debugpy                      1.6.6
# decorator                    5.1.1
# defusedxml                   0.7.1
# display-timedelta            1.1
# distlib                      0.3.7
# dnspython                    2.4.2
# docopt                       0.6.2
# exceptiongroup               1.1.3
# executing                    1.2.0
# fastjsonschema               2.18.1
# filelock                     3.13.1
# Fiona                        1.8.21
# Flask                        2.2.5
# Flask-Cors                   4.0.0
# Flask-WTF                    1.2.1
# flatbuffers                  23.1.21
# folium                       0.14.0
# fonttools                    4.33.3
# fqdn                         1.5.1
# future                       0.18.3
# gast                         0.4.0
# GDAL                         3.4.3
# geopandas                    0.14.0
# google-auth                  2.16.0
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.51.1
# gunicorn                     21.2.0
# h11                          0.14.0
# h5py                         3.8.0
# hyperlink                    21.0.0
# idna                         2.8
# incremental                  22.10.0
# ipykernel                    6.21.1
# ipython                      8.9.0
# ipywidgets                   8.1.1
# isoduration                  20.11.0
# itemadapter                  0.8.0
# itemloaders                  1.1.0
# itsdangerous                 2.1.2
# jedi                         0.18.2
# Jinja2                       3.1.2
# jmespath                     1.0.1
# joblib                       1.2.0
# Js2Py                        0.74
# json5                        0.9.14
# jsonpointer                  2.4
# jsonschema                   4.19.2
# jsonschema-specifications    2023.7.1
# jupyter                      1.0.0
# jupyter_client               8.0.2
# jupyter-console              6.6.3
# jupyter_core                 5.2.0
# jupyter-events               0.9.0
# jupyter-lsp                  2.2.0
# jupyter_server               2.10.0
# jupyter_server_terminals     0.4.4
# jupyterlab                   4.0.8
# jupyterlab-pygments          0.2.2
# jupyterlab_server            2.25.1
# jupyterlab-widgets           3.0.9
# kaggle                       1.5.16
# keras                        2.11.0
# kiwisolver                   1.4.2
# libclang                     15.0.6.1
# lxml                         4.9.3
# Markdown                     3.4.1
# MarkupSafe                   2.1.2
# matplotlib                   3.5.2
# matplotlib-inline            0.1.6
# mistune                      3.0.2
# munch                        4.0.0
# nbclient                     0.9.0
# nbconvert                    7.11.0
# nbformat                     5.9.2
# nest-asyncio                 1.5.6
# notebook                     7.0.6
# notebook_shim                0.2.3
# numpy                        1.22.4
# oauthlib                     3.2.2
# okpy                         1.18.1
# opencv-python                4.7.0.68
# opendatasets                 0.1.22
# opt-einsum                   3.3.0
# outcome                      1.3.0.post0
# overrides                    7.4.0
# packaging                    21.3
# pandas                       2.0.0
# pandocfilters                1.5.0
# parsel                       1.8.1
# parso                        0.8.3
# pickleshare                  0.7.5
# Pillow                       9.1.1
# pip                          23.3.1
# pipenv                       2023.10.24
# pipwin                       0.5.2
# platformdirs                 3.11.0
# plotly                       5.17.0
# prometheus-client            0.18.0
# prompt-toolkit               3.0.36
# Protego                      0.3.0
# protobuf                     3.19.6
# psutil                       5.9.4
# pure-eval                    0.2.2
# pyaes                        1.6.1
# pyasn1                       0.4.8
# pyasn1-modules               0.2.8
# pycparser                    2.21
# PyDispatcher                 2.0.7
# pygame                       2.1.2
# Pygments                     2.14.0
# PyHamcrest                   2.1.0
# pyjsparser                   2.7.1
# pymongo                      4.6.0
# pyOpenSSL                    23.3.0
# pyparsing                    3.0.9
# PyPrind                      2.11.3
# pyproj                       3.6.0
# pySmartDL                    1.3.4
# python-dateutil              2.8.2
# python-json-logger           2.0.7
# python-slugify               8.0.1
# pytutor                      1.0.0
# pytz                         2023.3
# pywin32                      305
# pywinpty                     2.0.12
# PyYAML                       6.0.1
# pyzmq                        25.0.0
# qtconsole                    5.5.1
# QtPy                         2.4.1
# queuelib                     1.6.2
# referencing                  0.30.2
# requests                     2.31.0
# requests-file                1.5.1
# requests-oauthlib            1.3.1
# retrying                     1.3.4
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rpds-py                      0.12.0
# rsa                          4.9
# scikit-learn                 1.2.1
# scipy                        1.10.0
# Scrapy                       2.11.0
# seaborn                      0.12.2
# selenium                     4.0.0
# Send2Trash                   1.8.2
# service-identity             23.1.0
# setuptools                   68.2.2
# shapely                      2.0.1
# six                          1.16.0
# sniffio                      1.3.0
# sortedcontainers             2.4.0
# soupsieve                    2.5
# stack-data                   0.6.2
# tenacity                     8.2.3
# tensorboard                  2.11.2
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.11.0
# tensorflow-estimator         2.11.0
# tensorflow-intel             2.11.0
# tensorflow-io-gcs-filesystem 0.30.0
# termcolor                    2.2.0
# terminado                    0.18.0
# text-unidecode               1.3
# threadpoolctl                3.1.0
# tinycss2                     1.2.1
# tldextract                   5.1.0
# tomli                        2.0.1
# tornado                      6.2
# tqdm                         4.66.1
# traitlets                    5.9.0
# trio                         0.23.1
# trio-websocket               0.11.1
# Twisted                      22.10.0
# twisted-iocpsupport          1.0.4
# types-python-dateutil        2.8.19.14
# typing_extensions            4.4.0
# tzdata                       2023.3
# tzlocal                      5.0.1
# uri-template                 1.3.0
# urllib3                      1.26.18
# urllib3-secure-extra         0.1.0
# virtualenv                   20.24.6
# w3lib                        2.1.2
# wcwidth                      0.2.6
# webcolors                    1.13
# webencodings                 0.5.1
# websocket-client             1.6.4
# Werkzeug                     2.2.2
# wheel                        0.38.4
# widgetsnbextension           4.0.9
# wrapt                        1.14.1
# wsproto                      1.2.0
# WTForms                      3.1.1
# zope.interface               6.1

# %%
chrome = webdriver.Chrome(executable_path=".\chromedriver.exe")
# Out:
# C:\Users\basti\AppData\Local\Temp\ipykernel_18084\1169974481.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   chrome = webdriver.Chrome(executable_path=".\chromedriver.exe")

# %% [markdown]
# Vous devez voir apparaître une nouvelle instance de votre navigateur. Si vous voulez accéder à une page :

# %%
chrome.get("https://www.amazon.fr")

# %% [markdown]
# Allez maintenant voir votre fenêtre. Vous êtes sur le site d'amazon. Vous pouvez maintenant vous déplacer dans la page. Pour cela il va falloir inspecter le code source de la page.
#
# Il existe de nombreuse méthode pour récupérer les éléments par exemple `find_element_by_link_text` qui permet de récupérer un élément grâce au text affiché. Ici, si on veut récupérer toutes les `Ventes Flash`

# %%
link = chrome.find_element_by_link_text("Voir toutes les Ventes Flash")
type(link)
# Out:
# C:\Users\basti\AppData\Local\Temp\ipykernel_18084\4015419568.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   link = chrome.find_element_by_link_text("Voir toutes les Ventes Flash")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 link = chrome.find_element_by_link_text("Voir toutes les Ventes Flash")
#       2 type(link)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:562, in WebDriver.find_element_by_link_text(self, link_text)
#     540 """
#     541 Finds an element by link text.
#     542
#    (...)
#     555         element = driver.find_element_by_link_text('Sign In')
#     556 """
#     557 warnings.warn(
#     558     "find_element_by_* commands are deprecated. Please use find_element() instead",
#     559     DeprecationWarning,
#     560     stacklevel=2,
#     561 )
# --> 562 return self.find_element(by=By.LINK_TEXT, value=link_text)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:1238, in WebDriver.find_element(self, by, value)
#    1235     by = By.CSS_SELECTOR
#    1236     value = '[name="%s"]' % value
# -> 1238 return self.execute(Command.FIND_ELEMENT, {
#    1239     'using': by,
#    1240     'value': value})['value']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:418, in WebDriver.execute(self, driver_command, params)
#     416 response = self.command_executor.execute(driver_command, params)
#     417 if response:
# --> 418     self.error_handler.check_response(response)
#     419     response['value'] = self._unwrap_value(
#     420         response.get('value', None))
#     421     return response
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"link text","selector":"Voir toutes les Ventes Flash"}
#   (Session info: chrome=119.0.6045.200)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF74E5882B2+55298]
# 	(No symbol) [0x00007FF74E4F5E02]
# 	(No symbol) [0x00007FF74E3B05AB]
# 	(No symbol) [0x00007FF74E3F175C]
# 	(No symbol) [0x00007FF74E3F18DC]
# 	(No symbol) [0x00007FF74E42CBC7]
# 	(No symbol) [0x00007FF74E4120EF]
# 	(No symbol) [0x00007FF74E42AAA4]
# 	(No symbol) [0x00007FF74E411E83]
# 	(No symbol) [0x00007FF74E3E670A]
# 	(No symbol) [0x00007FF74E3E7964]
# 	GetHandleVerifier [0x00007FF74E900AAB+3694587]
# 	GetHandleVerifier [0x00007FF74E95728E+4048862]
# 	GetHandleVerifier [0x00007FF74E94F173+4015811]
# 	GetHandleVerifier [0x00007FF74E6247D6+695590]
# 	(No symbol) [0x00007FF74E500CE8]
# 	(No symbol) [0x00007FF74E4FCF34]
# 	(No symbol) [0x00007FF74E4FD062]
# 	(No symbol) [0x00007FF74E4ED3A3]
# 	BaseThreadInitThunk [0x00007FFA0C047344+20]
# 	RtlUserThreadStart [0x00007FFA0C4E26B1+33]

# %% [markdown]
# Si on veut entrer dans le lien, il suffit d'appeler la méthode `click`.

# %%
link.click()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 link.click()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:80, in WebElement.click(self)
#      78 def click(self) -> None:
#      79     """Clicks the element."""
# ---> 80     self._execute(Command.CLICK_ELEMENT)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:693, in WebElement._execute(self, command, params)
#     691     params = {}
#     692 params['id'] = self._id
# --> 693 return self._parent.execute(command, params)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:418, in WebDriver.execute(self, driver_command, params)
#     416 response = self.command_executor.execute(driver_command, params)
#     417 if response:
# --> 418     self.error_handler.check_response(response)
#     419     response['value'] = self._unwrap_value(
#     420         response.get('value', None))
#     421     return response
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found
#   (Session info: chrome=119.0.6045.200)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF74E5882B2+55298]
# 	(No symbol) [0x00007FF74E4F5E02]
# 	(No symbol) [0x00007FF74E3B05AB]
# 	(No symbol) [0x00007FF74E3BE59A]
# 	(No symbol) [0x00007FF74E3B59E9]
# 	(No symbol) [0x00007FF74E3B4298]
# 	(No symbol) [0x00007FF74E3B6FDF]
# 	(No symbol) [0x00007FF74E3B70D0]
# 	(No symbol) [0x00007FF74E3F3265]
# 	(No symbol) [0x00007FF74E3E8586]
# 	(No symbol) [0x00007FF74E4120AA]
# 	(No symbol) [0x00007FF74E3E80CF]
# 	(No symbol) [0x00007FF74E4122C0]
# 	(No symbol) [0x00007FF74E42AAA4]
# 	(No symbol) [0x00007FF74E411E83]
# 	(No symbol) [0x00007FF74E3E670A]
# 	(No symbol) [0x00007FF74E3E7964]
# 	GetHandleVerifier [0x00007FF74E900AAB+3694587]
# 	GetHandleVerifier [0x00007FF74E95728E+4048862]
# 	GetHandleVerifier [0x00007FF74E94F173+4015811]
# 	GetHandleVerifier [0x00007FF74E6247D6+695590]
# 	(No symbol) [0x00007FF74E500CE8]
# 	(No symbol) [0x00007FF74E4FCF34]
# 	(No symbol) [0x00007FF74E4FD062]
# 	(No symbol) [0x00007FF74E4ED3A3]
# 	BaseThreadInitThunk [0x00007FFA0C047344+20]
# 	RtlUserThreadStart [0x00007FFA0C4E26B1+33]

# %%
link = chrome.find_element_by_link_text("Philips: une sélection de produits")
type(link)
link.click()
# Out:
# C:\Users\basti\AppData\Local\Temp\ipykernel_18084\2652263827.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   link = chrome.find_element_by_link_text("Philips: une sélection de produits")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 link = chrome.find_element_by_link_text("Philips: une sélection de produits")
#       2 type(link)
#       3 link.click()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:562, in WebDriver.find_element_by_link_text(self, link_text)
#     540 """
#     541 Finds an element by link text.
#     542
#    (...)
#     555         element = driver.find_element_by_link_text('Sign In')
#     556 """
#     557 warnings.warn(
#     558     "find_element_by_* commands are deprecated. Please use find_element() instead",
#     559     DeprecationWarning,
#     560     stacklevel=2,
#     561 )
# --> 562 return self.find_element(by=By.LINK_TEXT, value=link_text)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:1238, in WebDriver.find_element(self, by, value)
#    1235     by = By.CSS_SELECTOR
#    1236     value = '[name="%s"]' % value
# -> 1238 return self.execute(Command.FIND_ELEMENT, {
#    1239     'using': by,
#    1240     'value': value})['value']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:418, in WebDriver.execute(self, driver_command, params)
#     416 response = self.command_executor.execute(driver_command, params)
#     417 if response:
# --> 418     self.error_handler.check_response(response)
#     419     response['value'] = self._unwrap_value(
#     420         response.get('value', None))
#     421     return response
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"link text","selector":"Philips: une sélection de produits"}
#   (Session info: chrome=119.0.6045.200)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF74E5882B2+55298]
# 	(No symbol) [0x00007FF74E4F5E02]
# 	(No symbol) [0x00007FF74E3B05AB]
# 	(No symbol) [0x00007FF74E3F175C]
# 	(No symbol) [0x00007FF74E3F18DC]
# 	(No symbol) [0x00007FF74E42CBC7]
# 	(No symbol) [0x00007FF74E4120EF]
# 	(No symbol) [0x00007FF74E42AAA4]
# 	(No symbol) [0x00007FF74E411E83]
# 	(No symbol) [0x00007FF74E3E670A]
# 	(No symbol) [0x00007FF74E3E7964]
# 	GetHandleVerifier [0x00007FF74E900AAB+3694587]
# 	GetHandleVerifier [0x00007FF74E95728E+4048862]
# 	GetHandleVerifier [0x00007FF74E94F173+4015811]
# 	GetHandleVerifier [0x00007FF74E6247D6+695590]
# 	(No symbol) [0x00007FF74E500CE8]
# 	(No symbol) [0x00007FF74E4FCF34]
# 	(No symbol) [0x00007FF74E4FD062]
# 	(No symbol) [0x00007FF74E4ED3A3]
# 	BaseThreadInitThunk [0x00007FFA0C047344+20]
# 	RtlUserThreadStart [0x00007FFA0C4E26B1+33]

# %% [markdown]
# Vous êtes arrivé sur la page des ventes flash. Maintenant nous allons récupérer toutes les ventes actuelles. On remarque que les ventes sont stockés dans des widgets qui porte l'id `widgetContent`.

# %%
all_widgets = chrome.find_elements_by_id("octopus-dlp-asin-stream")
type(all_widgets), len(all_widgets)
# Out:
# C:\Users\basti\AppData\Local\Temp\ipykernel_18084\3873145521.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   all_widgets = chrome.find_elements_by_id("octopus-dlp-asin-stream")
# (list, 1)

# %% [markdown]
# On obtient une liste d'éléments décrits par cet identifiant. Il y en a 5, un pour chaque ligne. Pour récupérer les différentes offres de la première ligne. on récupère les sections correspondantes:

# %%
first_line = all_widgets[0]
all_first_line_elements = first_line.find_elements_by_class_name('a-section')
len(all_first_line_elements)
# Out:
# 241

# %% [markdown]
# Pour récupérer le text maintenant :

# %%
_ = [print(elt.text+ "\n")  for elt in all_first_line_elements]
# Out:
# Philips Electric Shaver Series 3000 - rasoir électrique Wet & Dry pour hommes avec technologie SkinProtect, couleur Noir, tondeuse rétractable, socle de recharge, housse de voyage (modèle S3342/13)
# 70
# Vente flash
# -33 %
# 59
# 99€ Prix récent le plus bas : 89,99 €
# Livraison GRATUITE en France métropolitaine. Détails
#
#
#
#
#
# Philips Electric Shaver Series 3000 - rasoir électrique Wet & Dry pour hommes avec technologie SkinProtect, couleur Noir, tondeuse rétractable, socle de recharge, housse de voyage (modèle S3342/13)
# 70
# Vente flash
# -33 %
# 59
# 99€ Prix récent le plus bas : 89,99 €
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Electric Shaver Series 3000 - rasoir électrique Wet & Dry pour hommes avec technologie SkinProtect, couleur Noir, tondeuse rétractable, socle de recharge, housse de voyage (modèle S3342/13)
#
# Vente flash
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Sonicare ProtectiveClean 5100 Brosse à dents électrique sonique + Assainisseur de têtes de brosse UV noir (modèle HX6850/57)
# 1 750
# Vente flash
# -33 %
# 79
# 99€ Prix récent le plus bas : 120,14 €
# Livraison GRATUITE en France métropolitaine. Détails
#
#
#
#
#
# Philips Sonicare ProtectiveClean 5100 Brosse à dents électrique sonique + Assainisseur de têtes de brosse UV noir (modèle HX6850/57)
# 1 750
# Vente flash
# -33 %
# 79
# 99€ Prix récent le plus bas : 120,14 €
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Sonicare ProtectiveClean 5100 Brosse à dents électrique sonique + Assainisseur de têtes de brosse UV noir (modèle HX6850/57)
#
# Vente flash
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips OneBlade 360 - lame de rechange, pour rasoir/tondeuse électrique OneBlade, avec sabot réglable 5 en 1, lot de 3, modèle QP437/50
# 73 219
# Vente flash
# -22 %
# 34
# 99€ (11,66 €/unité) Prix récent le plus bas : 44,99 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
# Il ne reste plus que 2 exemplaire(s) en s…
#
#
#
#
#
# Philips OneBlade 360 - lame de rechange, pour rasoir/tondeuse électrique OneBlade, avec sabot réglable 5 en 1, lot de 3, modèle QP437/50
# 73 219
# Vente flash
# -22 %
# 34
# 99€ (11,66 €/unité) Prix récent le plus bas : 44,99 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
# Il ne reste plus que 2 exemplaire(s) en s…
#
# Philips OneBlade 360 - lame de rechange, pour rasoir/tondeuse électrique OneBlade, avec sabot réglable 5 en 1, lot de 3, modèle QP437/50
#
# Vente flash
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Il ne reste plus que 2 exemplaire(s) en s…
#
# Philips Epilateur Satinelle Essentiel comportant 21 embouts et 2 réglages de vitesse (modèle BRE225/20)
# 13 015
# Vente flash
# -31 %
# 17
# 99€ Prix récent le plus bas : 26,00 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
#
#
#
#
# Philips Epilateur Satinelle Essentiel comportant 21 embouts et 2 réglages de vitesse (modèle BRE225/20)
# 13 015
# Vente flash
# -31 %
# 17
# 99€ Prix récent le plus bas : 26,00 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Epilateur Satinelle Essentiel comportant 21 embouts et 2 réglages de vitesse (modèle BRE225/20)
#
# Vente flash
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Series 5000 Tondeuse à barbe avec système Lift & Trim Pro (modèle BT5502/15)
# 4 299
# Vente flash
# -38 %
# 34
# 99€ Prix récent le plus bas : 56,57 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
#
#
#
#
# Philips Series 5000 Tondeuse à barbe avec système Lift & Trim Pro (modèle BT5502/15)
# 4 299
# Vente flash
# -38 %
# 34
# 99€ Prix récent le plus bas : 56,57 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Series 5000 Tondeuse à barbe avec système Lift & Trim Pro (modèle BT5502/15)
#
# Vente flash
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Sonicare for Kids Original Lot de 4 têtes de brosses à dents électriques soniques Compact, Bleu (Modèle HX6044/33)
# 3 312
# Vente flash
# -28 %
# 14
# 99€ (3,75 €/unité) Prix récent le plus bas : 20,93 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
#
#
#
#
# Philips Sonicare for Kids Original Lot de 4 têtes de brosses à dents électriques soniques Compact, Bleu (Modèle HX6044/33)
# 3 312
# Vente flash
# -28 %
# 14
# 99€ (3,75 €/unité) Prix récent le plus bas : 20,93 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Sonicare for Kids Original Lot de 4 têtes de brosses à dents électriques soniques Compact, Bleu (Modèle HX6044/33)
#
# Vente flash
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Épilateur compact sur secteur, Lumière intégrée Opti-light, Mini-épilateur zones sensibles et pince à épiler inclus (modèle BRP531/00)
# 4 269
# Vente flash
# -24 %
# 49
# 99€ Prix récent le plus bas : 65,59 €
# Livraison GRATUITE en France métropolitaine. Détails
#
#
#
#
#
# Philips Épilateur compact sur secteur, Lumière intégrée Opti-light, Mini-épilateur zones sensibles et pince à épiler inclus (modèle BRP531/00)
# 4 269
# Vente flash
# -24 %
# 49
# 99€ Prix récent le plus bas : 65,59 €
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Épilateur compact sur secteur, Lumière intégrée Opti-light, Mini-épilateur zones sensibles et pince à épiler inclus (modèle BRP531/00)
#
# Vente flash
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Rasoir électrique Série 5000 pour homme Wet & Dry, avec tondeuse rétractable, station de nettoyage, coffret de voyage et cartouche Quick Clean (modèle S5898/50)
# 4 612
# Vente flash
# -29 %
# 99
# 99€ Prix récent le plus bas : 139,99 €
# Livraison GRATUITE en France métropolitaine. Détails
#
#
#
#
#
# Philips Rasoir électrique Série 5000 pour homme Wet & Dry, avec tondeuse rétractable, station de nettoyage, coffret de voyage et cartouche Quick Clean (modèle S5898/50)
# 4 612
# Vente flash
# -29 %
# 99
# 99€ Prix récent le plus bas : 139,99 €
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Rasoir électrique Série 5000 pour homme Wet & Dry, avec tondeuse rétractable, station de nettoyage, coffret de voyage et cartouche Quick Clean (modèle S5898/50)
#
# Vente flash
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Sonicare For Kids Brosse à dents électrique sonique - Bleu (Modèle HX6322/04)
# 9 445
# Vente flash
# -10 %
# 29
# 99€ (29,99 €/unité) Prix récent le plus bas : 33,32 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
#
#
#
#
# Philips Sonicare For Kids Brosse à dents électrique sonique - Bleu (Modèle HX6322/04)
# 9 445
# Vente flash
# -10 %
# 29
# 99€ (29,99 €/unité) Prix récent le plus bas : 33,32 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Sonicare For Kids Brosse à dents électrique sonique - Bleu (Modèle HX6322/04)
#
# Vente flash
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Tondeuse Stylo, Visage/Corps, pour des Retouches Instantanées (modèle HP6393/00)
# 1 578
# Vente flash
# -46 %
# 19
# 99€ Prix récent le plus bas : 37,32 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
#
#
#
#
# Philips Tondeuse Stylo, Visage/Corps, pour des Retouches Instantanées (modèle HP6393/00)
# 1 578
# Vente flash
# -46 %
# 19
# 99€ Prix récent le plus bas : 37,32 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Tondeuse Stylo, Visage/Corps, pour des Retouches Instantanées (modèle HP6393/00)
#
# Vente flash
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Fer à lisser série 5000 avec technologie ThermoShield de couleur rose Pour Céramique, 37x12cm [modèle BHS520/00]
# 1 202
# Vente flash
# -36 %
# 39
# 99€ Prix récent le plus bas : 62,38 €
# Livraison GRATUITE en France métropolitaine. Détails
#
#
#
#
#
# Philips Fer à lisser série 5000 avec technologie ThermoShield de couleur rose Pour Céramique, 37x12cm [modèle BHS520/00]
# 1 202
# Vente flash
# -36 %
# 39
# 99€ Prix récent le plus bas : 62,38 €
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Fer à lisser série 5000 avec technologie ThermoShield de couleur rose Pour Céramique, 37x12cm [modèle BHS520/00]
#
# Vente flash
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Rasoir électrique Series 9000, chrome foncé, avec système de rasage Lift & Cut et technologie SkinIQ, tondeuse escamotable, stylet à barbe, socle de recharge, (modèle S9987/59)
# 1 746
# Vente flash
# -28 %
# 199
# 99€ Prix récent le plus bas : 276,99 €
# Livraison GRATUITE en France métropolitaine. Détails
#
#
#
#
#
# Philips Rasoir électrique Series 9000, chrome foncé, avec système de rasage Lift & Cut et technologie SkinIQ, tondeuse escamotable, stylet à barbe, socle de recharge, (modèle S9987/59)
# 1 746
# Vente flash
# -28 %
# 199
# 99€ Prix récent le plus bas : 276,99 €
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Rasoir électrique Series 9000, chrome foncé, avec système de rasage Lift & Cut et technologie SkinIQ, tondeuse escamotable, stylet à barbe, socle de recharge, (modèle S9987/59)
#
# Vente flash
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips One by Sonicare Brosse à dents à piles, Miami Corail (modèle HY1100/01)
# 2 137
# Vente flash
# -6 %
# 19
# 49€ Prix récent le plus bas : 20,82 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
#
#
#
#
# Philips One by Sonicare Brosse à dents à piles, Miami Corail (modèle HY1100/01)
# 2 137
# Vente flash
# -6 %
# 19
# 49€ Prix récent le plus bas : 20,82 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips One by Sonicare Brosse à dents à piles, Miami Corail (modèle HY1100/01)
#
# Vente flash
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Série 3000 Tondeuse cheveux et Multi-Styles comportant 9 Accessoires (modèle MG3740/15)
# 3 526
# Vente flash
# -21 %
# 29
# 99€ Prix récent le plus bas : 37,99 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
#
#
#
#
# Philips Série 3000 Tondeuse cheveux et Multi-Styles comportant 9 Accessoires (modèle MG3740/15)
# 3 526
# Vente flash
# -21 %
# 29
# 99€ Prix récent le plus bas : 37,99 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Série 3000 Tondeuse cheveux et Multi-Styles comportant 9 Accessoires (modèle MG3740/15)
#
# Vente flash
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Rasoir électrique S5000 pour homme Wet & Dry avec tondeuse rétractable intégrée, socle de charge et coffret de voyage (modèle S5884/35)
# 221
# Vente flash
# -25 %
# 89
# 99€ Prix récent le plus bas : 119,99 €
# Livraison GRATUITE en France métropolitaine. Détails
#
#
#
#
#
# Philips Rasoir électrique S5000 pour homme Wet & Dry avec tondeuse rétractable intégrée, socle de charge et coffret de voyage (modèle S5884/35)
# 221
# Vente flash
# -25 %
# 89
# 99€ Prix récent le plus bas : 119,99 €
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Rasoir électrique S5000 pour homme Wet & Dry avec tondeuse rétractable intégrée, socle de charge et coffret de voyage (modèle S5884/35)
#
# Vente flash
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips One by Sonicare Brosse à dents à piles, Mangue (modèle HY1100/02)
# 2 137
# Vente flash
# -6 %
# 19
# 49€ Prix récent le plus bas : 20,82 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
#
#
#
#
# Philips One by Sonicare Brosse à dents à piles, Mangue (modèle HY1100/02)
# 2 137
# Vente flash
# -6 %
# 19
# 49€ Prix récent le plus bas : 20,82 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips One by Sonicare Brosse à dents à piles, Mangue (modèle HY1100/02)
#
# Vente flash
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Série 7000 Tondeuse multi-usage lavable (modèle HC7650/15)
# 10 648
# Vente flash
# -9 %
# 49
# 99€ Prix récent le plus bas : 54,99 €
# Livraison GRATUITE en France métropolitaine. Détails
#
#
#
#
#
# Philips Série 7000 Tondeuse multi-usage lavable (modèle HC7650/15)
# 10 648
# Vente flash
# -9 %
# 49
# 99€ Prix récent le plus bas : 54,99 €
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Série 7000 Tondeuse multi-usage lavable (modèle HC7650/15)
#
# Vente flash
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Rasoir Philips Series 7000 - rasoir électrique Wet & Dry bleu glacier avec tondeuse rétractable intégrée, tondeuse à barbe, coffret de voyage, Quick Clean Pod et socle de charge (S7882/54)
# 4 332
# Vente flash
# -21 %
# 129
# 99€ Prix récent le plus bas : 165,28 €
# Livraison GRATUITE en France métropolitaine. Détails
#
#
#
#
#
# Philips Rasoir Philips Series 7000 - rasoir électrique Wet & Dry bleu glacier avec tondeuse rétractable intégrée, tondeuse à barbe, coffret de voyage, Quick Clean Pod et socle de charge (S7882/54)
# 4 332
# Vente flash
# -21 %
# 129
# 99€ Prix récent le plus bas : 165,28 €
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Rasoir Philips Series 7000 - rasoir électrique Wet & Dry bleu glacier avec tondeuse rétractable intégrée, tondeuse à barbe, coffret de voyage, Quick Clean Pod et socle de charge (S7882/54)
#
# Vente flash
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Epilateur 100 % étanche Séries 8000 avec 8 accessoires (Modèle BRE735/00)
# 3 397
# Vente flash
# -29 %
# 69
# 99€ Prix récent le plus bas : 97,90 €
# Livraison GRATUITE en France métropolitaine. Détails
#
#
#
#
#
# Philips Epilateur 100 % étanche Séries 8000 avec 8 accessoires (Modèle BRE735/00)
# 3 397
# Vente flash
# -29 %
# 69
# 99€ Prix récent le plus bas : 97,90 €
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Epilateur 100 % étanche Séries 8000 avec 8 accessoires (Modèle BRE735/00)
#
# Vente flash
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Series 5000 - Tondeuse tout-en-un, tondeuse multistyle 12 en 1 pour le visage, la tête et le corps, un seul outil complet et 14 hauteurs de coupe (de 0,5 à 16 mm) (modèle MG5950/15)
# 4 698
# Vente flash
# -11 %
# 47
# 49€ Prix récent le plus bas : 53,26 €
# Livraison GRATUITE en France métropolitaine. Détails
#
#
#
#
#
# Philips Series 5000 - Tondeuse tout-en-un, tondeuse multistyle 12 en 1 pour le visage, la tête et le corps, un seul outil complet et 14 hauteurs de coupe (de 0,5 à 16 mm) (modèle MG5950/15)
# 4 698
# Vente flash
# -11 %
# 47
# 49€ Prix récent le plus bas : 53,26 €
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Series 5000 - Tondeuse tout-en-un, tondeuse multistyle 12 en 1 pour le visage, la tête et le corps, un seul outil complet et 14 hauteurs de coupe (de 0,5 à 16 mm) (modèle MG5950/15)
#
# Vente flash
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Sèche-Cheveux Philips Série 3000 avec Fonction Ionique Avancée (modèle BHD351/10)
# 934
# Vente flash
# -10 %
# 17
# 99€ Prix récent le plus bas : 19,99 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
#
#
#
#
# Sèche-Cheveux Philips Série 3000 avec Fonction Ionique Avancée (modèle BHD351/10)
# 934
# Vente flash
# -10 %
# 17
# 99€ Prix récent le plus bas : 19,99 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Sèche-Cheveux Philips Série 3000 avec Fonction Ionique Avancée (modèle BHD351/10)
#
# Vente flash
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Céramique Fer à lisser série 5000 avec technologie ThermoShield, Rose [modèle BHS510/00] 37.1 x 12.1 x 6.4 cm
# 1 202
# Vente flash
# -18 %
# 32
# 99€ Prix récent le plus bas : 39,99 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
#
#
#
#
# Philips Céramique Fer à lisser série 5000 avec technologie ThermoShield, Rose [modèle BHS510/00] 37.1 x 12.1 x 6.4 cm
# 1 202
# Vente flash
# -18 %
# 32
# 99€ Prix récent le plus bas : 39,99 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Céramique Fer à lisser série 5000 avec technologie ThermoShield, Rose [modèle BHS510/00] 37.1 x 12.1 x 6.4 cm
#
# Vente flash
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Sèche-cheveux Séries 5000 (Modèle BHD530/00)
# 4 033
# Vente flash
# -31 %
# 44
# 99€ Prix récent le plus bas : 64,99 €
# Livraison GRATUITE en France métropolitaine. Détails
#
#
#
#
#
# Philips Sèche-cheveux Séries 5000 (Modèle BHD530/00)
# 4 033
# Vente flash
# -31 %
# 44
# 99€ Prix récent le plus bas : 64,99 €
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Sèche-cheveux Séries 5000 (Modèle BHD530/00)
#
# Vente flash
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# PHILIPS - BHS375/00 - Lisseur Essential/Technologie Thermoprotect avec Plaques en Céramique/Kératine
# 1 790
# Vente flash
# -14 %
# 18
# 99€ Prix récent le plus bas : 21,99 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
#
#
#
#
# PHILIPS - BHS375/00 - Lisseur Essential/Technologie Thermoprotect avec Plaques en Céramique/Kératine
# 1 790
# Vente flash
# -14 %
# 18
# 99€ Prix récent le plus bas : 21,99 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# PHILIPS - BHS375/00 - Lisseur Essential/Technologie Thermoprotect avec Plaques en Céramique/Kératine
#
# Vente flash
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Série 3000 - Sèche-cheveux ionique (modèle BHD360/20)
# 9 295
# Vente flash
# -22 %
# 23
# 49€ Prix récent le plus bas : 29,99 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
#
#
#
#
# Philips Série 3000 - Sèche-cheveux ionique (modèle BHD360/20)
# 9 295
# Vente flash
# -22 %
# 23
# 49€ Prix récent le plus bas : 29,99 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Série 3000 - Sèche-cheveux ionique (modèle BHD360/20)
#
# Vente flash
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Kit de coiffure, Series 3000, 1 600 W, accessoire ThermoProtect (modèle BHP398/00)
# 9 796
# Vente flash
# -39 %
# 26
# 99€ Prix récent le plus bas : 44,00 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
#
#
#
#
# Philips Kit de coiffure, Series 3000, 1 600 W, accessoire ThermoProtect (modèle BHP398/00)
# 9 796
# Vente flash
# -39 %
# 26
# 99€ Prix récent le plus bas : 44,00 €
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Kit de coiffure, Series 3000, 1 600 W, accessoire ThermoProtect (modèle BHP398/00)
#
# Vente flash
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Livraison gratuite sur votre première commande en France métropolitaine et en Belgique. Détails
#
# Philips Fer à friser automatique StyleCare Prestige avec système de boucles innovant (modèle BHB876/00)
# 8 539
# Vente flash
# -22 %
# 89
# 99€ Prix récent le plus bas : 114,99 €
# Livraison GRATUITE en France métropolitaine. Détails
#
#
#
#
#
# Philips Fer à friser automatique StyleCare Prestige avec système de boucles innovant (modèle BHB876/00)
# 8 539
# Vente flash
# -22 %
# 89
# 99€ Prix récent le plus bas : 114,99 €
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Fer à friser automatique StyleCare Prestige avec système de boucles innovant (modèle BHB876/00)
#
# Vente flash
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips éveil-lumière et simulateur d'aube, 25 intensités lumineuses, sons et musiques multiples, fonction de relaxation et de respiration (Modèle HF3651/01) Plastique, Blanc
# 2 461
# Vente flash
# -11 %
# 169
# 99€ Prix récent le plus bas : 189,99 €
# Livraison GRATUITE en France métropolitaine. Détails
#
#
#
#
#
# Philips éveil-lumière et simulateur d'aube, 25 intensités lumineuses, sons et musiques multiples, fonction de relaxation et de respiration (Modèle HF3651/01) Plastique, Blanc
# 2 461
# Vente flash
# -11 %
# 169
# 99€ Prix récent le plus bas : 189,99 €
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips éveil-lumière et simulateur d'aube, 25 intensités lumineuses, sons et musiques multiples, fonction de relaxation et de respiration (Modèle HF3651/01) Plastique, Blanc
#
# Vente flash
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Sonicare ProtectiveClean 4300 Alimenté par pile Lot de 2 brosses à dents électriques soniques avec capteur de pression (Modèle HX6807/35) Blanc
# 10 991
# Vente flash
# -9 %
# 78
# 99€ Prix récent le plus bas : 86,52 €
# Livraison GRATUITE en France métropolitaine. Détails
#
#
#
#
#
# Philips Sonicare ProtectiveClean 4300 Alimenté par pile Lot de 2 brosses à dents électriques soniques avec capteur de pression (Modèle HX6807/35) Blanc
# 10 991
# Vente flash
# -9 %
# 78
# 99€ Prix récent le plus bas : 86,52 €
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Sonicare ProtectiveClean 4300 Alimenté par pile Lot de 2 brosses à dents électriques soniques avec capteur de pression (Modèle HX6807/35) Blanc
#
# Vente flash
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Série 8000 Rasoir électrique Wet & Dry avec technologie SkinIQ noir, tondeuse rétractable, socle de charge, coffret de voyage, brossette de nettoyage (modèle S8696/35)
# 35
# Vente flash
# -6 %
# 157
# 99€ Prix récent le plus bas : 168,27 €
# Livraison GRATUITE en France métropolitaine. Détails
#
#
#
#
#
# Philips Série 8000 Rasoir électrique Wet & Dry avec technologie SkinIQ noir, tondeuse rétractable, socle de charge, coffret de voyage, brossette de nettoyage (modèle S8696/35)
# 35
# Vente flash
# -6 %
# 157
# 99€ Prix récent le plus bas : 168,27 €
# Livraison GRATUITE en France métropolitaine. Détails
#
# Philips Série 8000 Rasoir électrique Wet & Dry avec technologie SkinIQ noir, tondeuse rétractable, socle de charge, coffret de voyage, brossette de nettoyage (modèle S8696/35)
#
# Vente flash
#
# Livraison GRATUITE en France métropolitaine. Détails
#
# Livraison GRATUITE en France métropolitaine. Détails

# %% [markdown]
# Si vous êtes fan de JavaScript vous pouvez même injecter du code JS dans le navigateur depuis Python pour exécuter des opérations complexes.

# %%
js_script = """
const class_name = 'DRIOC'
console.log(`Hi from ${class_name}`)
"""

# %%
chrome.execute_script(js_script)

# %% [markdown]
# Vous pouvez aller vérifier dans la console Javascript du navigateur que le message apparait bien.

# %% [markdown]
# # Exercice

# %% [markdown]
# ## Exercice 1

# %% [markdown]
# Extraire le prix des offres :

# %%
# Extraire le texte de chaque WebElement
all_texts = [element.text.strip() for element in all_first_line_elements]

# Recherche des montants de prix dans la liste
prices = [re.search(r'\b(\d+,\d+)\b', text).group(1) for text in all_texts if re.search(r'\b(\d+,\d+)\b', text)]

# Afficher les prix extraits
for price in prices:
    print(f"Prix extrait : {price}")
# Out:
# Prix extrait : 89,99
# Prix extrait : 89,99
# Prix extrait : 120,14
# Prix extrait : 120,14
# Prix extrait : 11,66
# Prix extrait : 11,66
# Prix extrait : 26,00
# Prix extrait : 26,00
# Prix extrait : 56,57
# Prix extrait : 56,57
# Prix extrait : 3,75
# Prix extrait : 3,75
# Prix extrait : 65,59
# Prix extrait : 65,59
# Prix extrait : 139,99
# Prix extrait : 139,99
# Prix extrait : 29,99
# Prix extrait : 29,99
# Prix extrait : 37,32
# Prix extrait : 37,32
# Prix extrait : 62,38
# Prix extrait : 62,38
# Prix extrait : 276,99
# Prix extrait : 276,99
# Prix extrait : 20,82
# Prix extrait : 20,82
# Prix extrait : 37,99
# Prix extrait : 37,99
# Prix extrait : 119,99
# Prix extrait : 119,99
# Prix extrait : 20,82
# Prix extrait : 20,82
# Prix extrait : 54,99
# Prix extrait : 54,99
# Prix extrait : 165,28
# Prix extrait : 165,28
# Prix extrait : 97,90
# Prix extrait : 97,90
# Prix extrait : 0,5
# Prix extrait : 0,5
# Prix extrait : 0,5
# Prix extrait : 19,99
# Prix extrait : 19,99
# Prix extrait : 39,99
# Prix extrait : 39,99
# Prix extrait : 64,99
# Prix extrait : 64,99
# Prix extrait : 21,99
# Prix extrait : 21,99
# Prix extrait : 29,99
# Prix extrait : 29,99
# Prix extrait : 44,00
# Prix extrait : 44,00
# Prix extrait : 114,99
# Prix extrait : 114,99
# Prix extrait : 189,99
# Prix extrait : 189,99
# Prix extrait : 86,52
# Prix extrait : 86,52
# Prix extrait : 168,27
# Prix extrait : 168,27

# %%
def extract_price(offer_web_element):
    raise NotImplementedError('Need to be implemented')
    pass

extract_price(all_first_line_elements[0])

# %% [markdown]
# Extraire l'image de l'offre:

# %%
def extract_image(offer_web_element):
    raise NotImplementedError('Need to be implemented')
    pass

extract_image(all_first_line_elements[0])

# %% [markdown]
# Extraire le titre de l'offre:

# %%
def extract_title(offer_web_element):
    raise NotImplementedError('Need to be implemented')
    pass

extract_title(all_first_line_elements[0])

# %%
chrome.close()
